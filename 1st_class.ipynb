# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanrajR007/Gen_AI_NXTWAVE/blob/main/1st_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install -U google-genai

# %%
from google import genai
from google.colab import userdata

# %%
api = userdata.get("GEMENI_API_KEY")
client = genai.Client(api_key = api)
#print(client)

# %%
def study_assistant(user_prompt):
  res = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=user_prompt
  )
  return res

# %%
prompt = "what is ai explain in 20 words"
ans=study_assistant(prompt)
print(ans.text)
# Out:
# AI enables machines to mimic human intelligence: learning, problem-solving, perception, and decision-making to perform tasks autonomously.
